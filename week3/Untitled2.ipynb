# %% [markdown]
# <a href="https://colab.research.google.com/github/DHKIII/ml/blob/main/week3/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Task 1**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
cd "/content/drive/My Drive/Hands-On-Data-Analysis-with-Pandas-2nd-edition/ch_02"
# Out:
# /content/drive/My Drive/Hands-On-Data-Analysis-with-Pandas-2nd-edition/ch_02

# %%
import pandas as pd
df = pd.read_csv('data/earthquakes.csv')

# %%
df.loc[3:10, ['mag', 'magType', 'type']]
# Out:
#      mag magType        type
# 3   0.44      ml  earthquake
# 4   2.16      md  earthquake
# 5   2.61      md  earthquake
# 6   1.70      ml  earthquake
# 7   1.13      md  earthquake
# 8   0.92      md  earthquake
# 9   4.70      mb  earthquake
# 10  0.50      ml  earthquake

# %%
df.columns
# Out:
# Index(['alert', 'cdi', 'code', 'detail', 'dmin', 'felt', 'gap', 'ids', 'mag',
#        'magType', 'mmi', 'net', 'nst', 'place', 'rms', 'sig', 'sources',
#        'status', 'time', 'title', 'tsunami', 'type', 'types', 'tz', 'updated',
#        'url'],
#       dtype='object')

# %%
df.iloc[3:10, [8, 9, 21]]
# Out:
#     mag magType        type
# 3  0.44      ml  earthquake
# 4  2.16      md  earthquake
# 5  2.61      md  earthquake
# 6  1.70      ml  earthquake
# 7  1.13      md  earthquake
# 8  0.92      md  earthquake
# 9  4.70      mb  earthquake

# %%
df.loc[(df.place.str.contains('Arizona')), ['mag', 'magType', 'place', 'title', 'type']]
# Out:
#        mag magType                              place  \
# 1062  1.23      ml  7km SSW of Colorado City, Arizona
# 3965  0.94      md  7km WSW of Colorado City, Arizona
#
#                                           title        type
# 1062  M 1.2 - 7km SSW of Colorado City, Arizona  earthquake
# 3965  M 0.9 - 7km WSW of Colorado City, Arizona  earthquake

# %%
df.loc[[df.mag.idxmax()], ['mag', 'magType', 'place', 'title', 'type']]
# Out:
#       mag magType                      place  \
# 5263  7.5     mww  78km N of Palu, Indonesia
#
#                                   title        type
# 5263  M 7.5 - 78km N of Palu, Indonesia  earthquake

# %%
df_2 = df.sort_values(by=['mag'], axis=0, ascending=False)
df_2[['mag', 'magType', 'place', 'title', 'type']][1:10]
# Out:
#       mag magType                                place  \
# 837   7.0     mww   117km E of Kimbe, Papua New Guinea
# 4363  6.7     mww       263km NNE of Ndoi Island, Fiji
# 118   6.7     mww      262km NW of Ozernovskiy, Russia
# 799   6.5     mww   148km S of Severo-Kuril'sk, Russia
# 816   6.2     mww  94km SW of Kokopo, Papua New Guinea
# 838   6.1      mb   132km E of Kimbe, Papua New Guinea
# 5323  6.1     mww          55km NNW of Palu, Indonesia
# 9211  6.0     mww               Southwest Indian Ridge
# 862   6.0     mww   39km NNE of Sumberanyar, Indonesia
#
#                                             title        type
# 837    M 7.0 - 117km E of Kimbe, Papua New Guinea  earthquake
# 4363       M 6.7 - 263km NNE of Ndoi Island, Fiji  earthquake
# 118       M 6.7 - 262km NW of Ozernovskiy, Russia  earthquake
# 799    M 6.5 - 148km S of Severo-Kuril'sk, Russia  earthquake
# 816   M 6.2 - 94km SW of Kokopo, Papua New Guinea  earthquake
# ...

# %% [markdown]
# **Task 2**

# %%
del df['alert']
df.columns
# Out:
# Index(['cdi', 'code', 'detail', 'dmin', 'felt', 'gap', 'ids', 'mag', 'magType',
#        'mmi', 'net', 'nst', 'place', 'rms', 'sig', 'sources', 'status', 'time',
#        'title', 'tsunami', 'type', 'types', 'tz', 'updated', 'url'],
#       dtype='object')

# %%
mag = df.pop('mag')
magType = df.pop('magType')
df.columns
# Out:
# Index(['cdi', 'code', 'detail', 'dmin', 'felt', 'gap', 'ids', 'mmi', 'net',
#        'nst', 'place', 'rms', 'sig', 'sources', 'status', 'time', 'title',
#        'tsunami', 'type', 'types', 'tz', 'updated', 'url'],
#       dtype='object')

# %%
pd.concat([mag, magType], axis = 1)
# Out:
#        mag magType
# 0     1.35      ml
# 1     1.29      ml
# 2     3.42      ml
# 3     0.44      ml
# 4     2.16      md
# ...    ...     ...
# 9327  0.62      md
# 9328  1.00      ml
# 9329  2.40      md
# 9330  1.10      ml
# 9331  0.66      ml
#
# [9332 rows x 2 columns]
