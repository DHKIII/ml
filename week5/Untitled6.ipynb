# %% [markdown]
# <a href="https://colab.research.google.com/github/DHKIII/ml/blob/main/week5/Untitled6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
cd "/content/drive/My Drive/Hands-On-Data-Analysis-with-Pandas-2nd-edition/ch_04"
# Out:
# /content/drive/My Drive/Hands-On-Data-Analysis-with-Pandas-2nd-edition/ch_04

# %%
import numpy as np
import pandas as pd

weather = pd.read_csv('data/nyc_weather_2018.csv')

# %%
practice = weather.query('datatype=="PRCP" and station.str.contains("S0007")')
practice.head()
# Out:
#                      date datatype            station attributes  value
# 79    2018-01-01T00:00:00     PRCP  GHCND:US1NYNS0007       ,,N,    0.0
# 311   2018-01-02T00:00:00     PRCP  GHCND:US1NYNS0007       ,,N,    0.0
# 545   2018-01-03T00:00:00     PRCP  GHCND:US1NYNS0007       ,,N,    0.0
# 788   2018-01-04T00:00:00     PRCP  GHCND:US1NYNS0007       ,,N,    4.1
# 1044  2018-01-05T00:00:00     PRCP  GHCND:US1NYNS0007       ,,N,   18.0

# %%
station_info = pd.read_csv('data/weather_stations.csv')

# %%
weather.attributes.describe()
# Out:
# count     78780
# unique       26
# top        ,,N,
# freq      34153
# Name: attributes, dtype: object

# %%
pd=weather.query('datatype=="PRCP"').groupby(level=0).mean()
pd
# Out:
# <ipython-input-13-a19847a34be1>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   pd=weather.query('datatype=="PRCP"').groupby(level=0).mean()
#        value
# 0        0.0
# 1        0.0
# 3        0.0
# 6        0.0
# 9        0.0
# ...      ...
# 78736   28.7
# 78743   25.9
# 78751   29.2
# 78760   24.4
# 78768   31.2
#
# [27228 rows x 1 columns]
